# %%
from nilearn.image import threshold_img, load_img, math_img, resample_to_img, new_img_like
from nilearn.plotting import plot_stat_map, plot_roi

# %%
putamen_mask = '/mnt/data/learning-habits/masks/MNI152NLin2009cAsym/putamen_AAL_MNI152NLin2009cAsym.nii'
sample_voi_mask = '/mnt/data/learning-habits/spm_format_noSDC/outputs/glm2_chosen_all_runs_scrubbed_2025-12-11-11-22/sub-01/VOI_putamen_sess1_mask.nii'

# %%
putamen_mask = load_img(putamen_mask)
sample_voi_mask = load_img(sample_voi_mask)

# %%
putamen_voxels = putamen_mask.get_fdata().sum()
sample_voi_voxels = sample_voi_mask.get_fdata().sum()

print(f"Putamen mask voxels: {putamen_voxels}")
print(f"Sample VOI mask voxels: {sample_voi_voxels}")
# Out:
# Putamen mask voxels: 500.0
# Sample VOI mask voxels: 500.0
