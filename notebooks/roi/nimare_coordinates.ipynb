# %% [markdown]
# # Neurosynth Coordinate Decoder
#
# Given a list of MNI coordinates, query the Neurosynth database (v7) for the most strongly associated cognitive terms.
#
# Uses an association test: z-score comparing term frequency in studies activating near the seed coordinate vs. all studies in the database.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import pandas as pd
import scipy.sparse as sp
from pathlib import Path
from IPython.display import display

# Where to store / look for the Neurosynth v7 data files
NS_DATA_DIR = Path.home() / 'data' / 'ns_data' / 'neurosynth'

# Search radius in mm around each coordinate
RADIUS_MM = 10

# Number of top terms to display per coordinate
N_TOP_TERMS = 15

# %% [markdown]
# ## Load Neurosynth data

# %%
from nimare.extract import fetch_neurosynth

# NS_DATA_DIR.mkdir(parents=True, exist_ok=True)
# fetch_neurosynth(str(NS_DATA_DIR.parent), version='7', overwrite=False)

print('Loading coordinates...')
coords_df = pd.read_csv(NS_DATA_DIR / 'data-neurosynth_version-7_coordinates.tsv.gz', sep='\t')
study_ids = sorted(coords_df['id'].unique())
id_to_idx = {sid: i for i, sid in enumerate(study_ids)}
print(f'  {len(coords_df)} peaks across {len(study_ids)} studies')

print('Loading vocabulary...')
with open(NS_DATA_DIR / 'data-neurosynth_version-7_vocab-terms_vocabulary.txt') as f:
    vocab = [line.strip() for line in f]
print(f'  {len(vocab)} terms')

print('Loading term features...')
features = sp.load_npz(NS_DATA_DIR / 'data-neurosynth_version-7_vocab-terms_source-abstract_type-tfidf_features.npz')
feat_bin = (features > 0).toarray()
p_term_global = feat_bin.mean(axis=0)
print(f'  feature matrix: {features.shape}')
# Out:
# Loading coordinates...
#   507891 peaks across 14371 studies
# Loading vocabulary...
#   3228 terms
# Loading term features...
#   feature matrix: (14371, 3228)

# %% [markdown]
# ## Functions

# %%
def decode_coordinate(x, y, z, radius=RADIUS_MM, n_top=N_TOP_TERMS):
    """Return top Neurosynth terms for a coordinate.

    Parameters
    ----------
    x, y, z : int or float
        MNI coordinates in mm.
    radius : float
        Search radius in mm.
    n_top : int
        Number of top terms to return.

    Returns
    -------
    pd.DataFrame with columns: term, z_score, p_active, p_global, n_studies
    """
    dists = np.sqrt(
        (coords_df['x'] - x)**2 +
        (coords_df['y'] - y)**2 +
        (coords_df['z'] - z)**2
    )
    nearby_ids = set(coords_df.loc[dists <= radius, 'id'].unique())
    active_idx = [id_to_idx[sid] for sid in nearby_ids if sid in id_to_idx]
    n_active = len(active_idx)

    if n_active == 0:
        print(f'  Warning: no studies found within {radius}mm of ({x},{y},{z})')
        return pd.DataFrame()

    mask = np.zeros(len(study_ids), dtype=bool)
    mask[active_idx] = True

    p_active = feat_bin[mask].mean(axis=0)
    se = np.sqrt(p_term_global * (1 - p_term_global) / n_active + 1e-10)
    z_scores = (p_active - p_term_global) / se

    top_idx = np.argsort(z_scores)[::-1][:n_top]
    return pd.DataFrame({
        'term':      [vocab[i] for i in top_idx],
        'z_score':   np.round(z_scores[top_idx], 2),
        'p_active':  np.round(p_active[top_idx], 3),
        'p_global':  np.round(p_term_global[top_idx], 3),
        'n_studies': n_active,
    })


def decode_and_display(coords):
    """Decode a list of (x, y, z, label) tuples and display results."""
    results = {}
    for x, y, z, label in coords:
        df = decode_coordinate(x, y, z)
        results[(x, y, z, label)] = df
        print(f'\n━━━ ({x}, {y}, {z})  {label}  [n={df["n_studies"].iloc[0]} studies] ━━━')
        display(df[['term', 'z_score', 'p_active', 'p_global']].reset_index(drop=True))
    return results

# %% [markdown]
# ---
# ## PPI — whole-brain clusters (FWE cluster-corrected, p < 0.05)
#
# Seed: posterior putamen (from GLM2 chosen H-value peak). Modulator: chosen H-values at second stimulus onset.
#
# 9 clusters survive whole-brain FWE correction (forming threshold p < 0.001). Decoding only the 5 retained for interpretation (bold in LH - PPI note); occipital/cerebellar clusters excluded.

# %%
ppi_clusters = [
    (-24, -21,  -8,  'Hippocampus'),
    (-33,  33,  -1,  'Insula / IFC'),
    (-48,  30,  27,  'Middle frontal gyrus (L)'),
    (-48, -30,  37.5,'Postcentral gyrus'),
    ( 45,  33,  30.5,'Middle frontal gyrus (R)'),
    (45, -60, 30.5, 'Angular gyrus (R)'),
]

ppi_results = decode_and_display(ppi_clusters)
# Out:
# ━━━ (-24, -21, -8)  Hippocampus  [n=1072 studies] ━━━
#                        term  z_score  p_active  p_global
# 0               hippocampus    19.64     0.230     0.074
# 1               hippocampal    14.41     0.125     0.039
# 2           medial temporal    13.76     0.105     0.032
# 3          autobiographical    11.18     0.044     0.010
# 4                  lobe mtl     9.95     0.034     0.007
# 5                       mtl     9.56     0.038     0.010
# 6                 retrieval     9.33     0.129     0.061
# 7                    memory     8.81     0.297     0.191
# 8                  episodic     8.53     0.081     0.034
# 9                  encoding     8.43     0.123     0.061
# 10  autobiographical memory     8.31     0.025     0.006
# 11                 amygdala     8.03     0.187     0.110
# 12                   recall     7.99     0.049     0.017
# 13            temporal lobe     7.69     0.093     0.045
# 14          parahippocampal     7.33     0.087     0.042
# ━━━ (-33, 33, -1)  Insula / IFC  [n=1335 studies] ━━━
#                 term  z_score  p_active  p_global
# 0   inferior frontal     8.29     0.208     0.132
# 1              words     6.72     0.112     0.066
# 2       orthographic     6.52     0.026     0.009
# 3            frontal     6.06     0.407     0.329
# 4           inferior     6.04     0.305     0.235
# 5           semantic     5.86     0.113     0.072
# 6       phonological     5.82     0.052     0.026
# 7           language     5.53     0.117     0.077
# 8    anterior insula     5.38     0.079     0.047
# 9             insula     5.25     0.190     0.140
# 10         retrieval     5.04     0.094     0.061
# 11              verb     4.74     0.021     0.009
# 12         processes     4.59     0.222     0.174
# 13         presented     4.49     0.152     0.113
# 14           reading     4.33     0.058     0.036
# ━━━ (-48, 30, 27)  Middle frontal gyrus (L)  [n=1395 studies] ━━━
#                        term  z_score  p_active  p_global
# 0                    memory    11.96     0.317     0.191
# 1            working memory    11.03     0.154     0.076
# 2                   working    10.83     0.156     0.078
# 3              dorsolateral     9.40     0.161     0.089
# 4                prefrontal     9.11     0.419     0.306
# 5                      task     8.27     0.526     0.417
# 6                 memory wm     8.22     0.047     0.018
# 7                 retrieval     8.11     0.113     0.061
# 8                   demands     8.08     0.085     0.041
# 9                     tasks     7.90     0.232     0.155
# 10  dorsolateral prefrontal     7.22     0.123     0.073
# 11       lateral prefrontal     7.06     0.054     0.025
# 12        prefrontal cortex     6.92     0.304     0.226
# 13                       wm     6.90     0.052     0.024
# 14             phonological     6.60     0.054     0.026
# ━━━ (-48, -30, 37.5)  Postcentral gyrus  [n=1171 studies] ━━━
#                       term  z_score  p_active  p_global
# 0                    motor    11.14     0.303     0.178
# 1                 parietal    11.06     0.434     0.288
# 2                     hand    10.05     0.132     0.061
# 3                 premotor     9.90     0.147     0.072
# 4                movements     8.86     0.102     0.047
# 5                   action     8.85     0.124     0.062
# 6                   finger     8.41     0.060     0.023
# 7                  actions     8.30     0.094     0.044
# 8        inferior parietal     8.11     0.145     0.081
# 9            motor imagery     7.77     0.026     0.007
# 10           somatosensory     7.61     0.094     0.047
# 11                 tactile     7.45     0.043     0.016
# 12           intraparietal     7.39     0.092     0.047
# 13                grasping     7.29     0.023     0.006
# 14  anterior intraparietal     7.12     0.022     0.006
# ━━━ (45, 33, 30.5)  Middle frontal gyrus (R)  [n=1386 studies] ━━━
#                        term  z_score  p_active  p_global
# 0                   working    13.63     0.177     0.078
# 1            working memory    13.36     0.171     0.076
# 2              dorsolateral    12.42     0.185     0.089
# 3                prefrontal    11.75     0.452     0.306
# 4   dorsolateral prefrontal    11.44     0.153     0.073
# 5         prefrontal cortex    10.41     0.343     0.226
# 6                    memory     9.39     0.290     0.191
# 7                      task     8.66     0.532     0.417
# 8                      load     8.64     0.062     0.025
# 9                  parietal     8.63     0.392     0.288
# 10                    dlpfc     8.57     0.076     0.034
# 11              memory load     8.42     0.023     0.006
# 12                executive     8.06     0.104     0.055
# 13       lateral prefrontal     7.81     0.058     0.025
# 14                    tasks     7.80     0.231     0.155
# ━━━ (45, -60, 30.5)  Angular gyrus (R)  [n=1021 studies] ━━━
#                      term  z_score  p_active  p_global
# 0                 default    15.00     0.177     0.063
# 1            default mode    14.36     0.156     0.054
# 2                    mode    13.64     0.162     0.060
# 3            mode network    13.18     0.131     0.045
# 4                     dmn    11.52     0.082     0.025
# 5             network dmn    11.34     0.076     0.023
# 6                 network     9.13     0.409     0.281
# 7                 angular     9.13     0.073     0.027
# 8                networks     8.94     0.232     0.136
# 9           angular gyrus     8.83     0.062     0.022
# 10    posterior cingulate     8.67     0.133     0.066
# 11                resting     7.92     0.186     0.109
# 12                   rest     7.61     0.076     0.034
# 13          resting state     7.55     0.169     0.099
# 14  independent component     7.54     0.060     0.024

# %% [markdown]
# ---
# ## GLM3 — chosen choice variable model (supplementary)
#
# Parametric modulator: chosen choice variable (Q+H combination). 4 clusters retained for interpretation
# (bold in GLM3 - choice variable note); cerebellum, occipital, and WM clusters excluded.
# Whole-brain FWE cluster-corrected (forming threshold p < 0.001, cluster p < 0.05 FWE).

# %%
glm3_clusters = [
    (-30, -18,  -1,   'Left Putamen'),
    (-33, -45,  69,   'Postcentral gyrus (L)'),
    ( 39,  -6, -25.5, 'Right Putamen'),
    (  3, -51,  69,   'Postcentral gyrus (R)'),
]

glm3_results = decode_and_display(glm3_clusters)
# Out:
# ━━━ (-30, -18, -1)  Left Putamen  [n=780 studies] ━━━
#                term  z_score  p_active  p_global
# 0             basal     8.95     0.100     0.038
# 1           putamen     8.69     0.104     0.042
# 2     basal ganglia     8.50     0.088     0.034
# 3           ganglia     8.46     0.088     0.034
# 4       hippocampus     6.10     0.131     0.074
# 5             paced     6.06     0.026     0.007
# 6          striatal     5.70     0.077     0.038
# 7          striatum     5.20     0.106     0.062
# 8        structures     5.08     0.112     0.066
# 9            insula     4.90     0.201     0.140
# 10  medial temporal     4.75     0.062     0.032
# 11             rich     4.64     0.019     0.006
# 12      subcortical     4.63     0.079     0.045
# 13           finger     4.56     0.047     0.023
# 14       anisotropy     4.45     0.028     0.011
# ━━━ (-33, -45, 69)  Postcentral gyrus (L)  [n=396 studies] ━━━
#                   term  z_score  p_active  p_global
# 0             premotor    11.16     0.217     0.072
# 1                 hand    10.02     0.182     0.061
# 2                motor     8.97     0.351     0.178
# 3      dorsal premotor     8.59     0.063     0.013
# 4                 limb     8.32     0.048     0.009
# 5             parietal     8.23     0.475     0.288
# 6        motor imagery     7.79     0.040     0.007
# 7               action     7.64     0.154     0.062
# 8    superior parietal     7.37     0.119     0.043
# 9   action observation     7.10     0.040     0.008
# 10           movements     6.99     0.121     0.047
# 11               video     6.94     0.053     0.013
# 12     premotor cortex     6.90     0.111     0.042
# 13    ventral premotor     6.64     0.051     0.013
# 14     parietal cortex     6.37     0.159     0.075
# ━━━ (39, -6, -25.5)  Right Putamen  [n=530 studies] ━━━
#                  term  z_score  p_active  p_global
# 0            amygdala    12.75     0.283     0.110
# 1         hippocampus     9.97     0.187     0.074
# 2         hippocampal     8.74     0.113     0.039
# 3       temporal lobe     6.36     0.102     0.045
# 4               faces     6.05     0.123     0.060
# 5   amygdala anterior     6.05     0.025     0.005
# 6     medial temporal     5.99     0.077     0.032
# 7    lateral temporal     5.96     0.032     0.008
# 8            temporal     5.71     0.430     0.315
# 9            pictures     5.54     0.085     0.039
# 10          emotional     5.37     0.194     0.119
# 11  anterior temporal     5.21     0.040     0.013
# 12              heart     5.07     0.023     0.006
# 13               face     5.02     0.115     0.062
# 14        personality     4.97     0.053     0.022
# ━━━ (3, -51, 69)  Postcentral gyrus (R)  [n=315 studies] ━━━
#                       term  z_score  p_active  p_global
# 0                precuneus     5.67     0.152     0.071
# 1               compensate     4.73     0.029     0.007
# 2    independent component     4.62     0.063     0.024
# 3   somatosensory cortices     4.40     0.029     0.007
# 4            somatosensory     4.32     0.098     0.047
# 5        motor performance     4.10     0.022     0.005
# 6               navigation     4.10     0.022     0.005
# 7                  central     4.08     0.117     0.062
# 8            sensory motor     4.06     0.038     0.013
# 9         gyrus cerebellum     4.01     0.025     0.007
# 10       superior parietal     3.98     0.089     0.043
# 11                networks     3.96     0.213     0.136
# 12                    foot     3.85     0.022     0.006
# 13            central role     3.55     0.025     0.008
# 14              identified     3.51     0.159     0.100

# %% [markdown]
# ---
# ## GLM2 chosen — premotor H-value peak
#
# Contrast: chosen H-value at second stimulus onset. Motor mask SVC survives correction.
#
# - **Whole-brain peak**: (24, −45, 62) — postcentral/premotor cluster
# - **SVC peak (premotor mask)**: (48, −6, 20) — survives SVC, but 94/98 voxels WM; decoding included for completeness

# %%
glm2_chosen_premotor_clusters = [
    (24, -45, 62,  "Postcentral/premotor (whole-brain peak)"),
    (48,  -6, 20,  "Premotor SVC peak (mostly WM — interpret with caution)"),
]

glm2_chosen_premotor_results = decode_and_display(glm2_chosen_premotor_clusters)
# Out:
# ━━━ (24, -45, 62)  Postcentral/premotor (whole-brain peak)  [n=580 studies] ━━━
#                       term  z_score  p_active  p_global
# 0                 parietal     8.74     0.452     0.288
# 1                movements     8.60     0.122     0.047
# 2                    motor     7.97     0.305     0.178
# 3            contralateral     7.63     0.086     0.031
# 4            somatosensory     7.62     0.114     0.047
# 5                 premotor     7.58     0.153     0.072
# 6        superior parietal     7.32     0.105     0.043
# 7                     hand     6.68     0.128     0.061
# 8                  tactile     6.66     0.050     0.016
# 9                  primary     6.54     0.166     0.088
# 10                   paced     6.27     0.029     0.007
# 11  somatosensory cortices     6.17     0.029     0.007
# 12       primary secondary     5.72     0.026     0.007
# 13            sensorimotor     5.34     0.095     0.048
# 14             observation     5.32     0.059     0.024
# ━━━ (48, -6, 20)  Premotor SVC peak (mostly WM — interpret with caution)  [n=665 studies] ━━━
#                       term  z_score  p_active  p_global
# 0         posterior insula     7.74     0.045     0.012
# 1            somatosensory     6.94     0.104     0.047
# 2                       s1     6.80     0.027     0.006
# 3                   insula     6.44     0.227     0.140
# 4              postcentral     6.23     0.054     0.020
# 5   somatosensory cortices     5.93     0.027     0.007
# 6               production     5.87     0.056     0.022
# 7                    motor     5.20     0.256     0.178
# 8      sensorimotor cortex     5.01     0.033     0.012
# 9        postcentral gyrus     5.00     0.035     0.013
# 10       speech production     4.98     0.024     0.007
# 11                 noxious     4.88     0.021     0.006
# 12                    pain     4.82     0.071     0.036
# 13            sensorimotor     4.80     0.087     0.048
# 14               brainstem     4.68     0.032     0.012

# %% [markdown]
# ---
# ## RSA searchlight — frequency and value×frequency interaction (2026-09-03)
#
# Cluster-FWE-corrected peaks (permutation, `run_rsa_group_stats.py`) from
# `multivariate/rsa_searchlight_results.ipynb` §12, primary peaks only (no
# sub-peaks). Labels combine the anatomical name from `utils.atlas.label_coordinates`
# (§13 of that notebook) with the term and cluster number, for cross-reference.

# %%
rsa_freq_clusters = [
    (-48, -81,  -1,   'Frequency c1: Fusiform/lat. occipital (L)'),
    ( 42, -54, -18.5, 'Frequency c2: Fusiform/lat. occipital (R)'),
    ( 42,  12, -18.5, 'Frequency c3: Temporal pole (R)'),
    (-24, -81,  34,   'Frequency c4: Lateral occipital, superior (L)'),
    ( -3,   9,  -1,   'Frequency c5: Subcallosal cortex'),
    ( 57,  18,  23.5, 'Frequency c6: IFG pars opercularis (R)'),
    (  0, -93,  -8,   'Frequency c7: Occipital pole'),
]

rsa_freq_results = decode_and_display(rsa_freq_clusters)
# Out:
# ━━━ (-48, -81, -1)  Frequency c1: Fusiform/lat. occipital (L)  [n=865 studies] ━━━
#                   term  z_score  p_active  p_global
# 0               visual    14.10     0.414     0.216
# 1            occipital    12.40     0.230     0.102
# 2    lateral occipital    10.22     0.059     0.016
# 3               motion     9.72     0.089     0.031
# 4     occipitotemporal     8.78     0.045     0.012
# 5                   v5     8.59     0.032     0.007
# 6                   mt     8.36     0.038     0.010
# 7     occipital cortex     8.12     0.066     0.024
# 8               videos     7.92     0.030     0.007
# 9   action observation     7.87     0.032     0.008
# 10         observation     7.66     0.065     0.024
# 11   occipito temporal     7.32     0.038     0.012
# 12             objects     7.20     0.101     0.048
# 13        extrastriate     7.13     0.049     0.017
# 14          perception     7.06     0.157     0.089
# ━━━ (42, -54, -18.5)  Frequency c2: Fusiform/lat. occipital (R)  [n=1317 studies] ━━━
#                  term  z_score  p_active  p_global
# 0                face    23.12     0.216     0.062
# 1            fusiform    22.49     0.223     0.068
# 2               faces    20.27     0.193     0.060
# 3       fusiform face    18.02     0.059     0.010
# 4                 ffa    16.30     0.044     0.007
# 5            face ffa    15.05     0.038     0.006
# 6      fusiform gyrus    14.49     0.119     0.040
# 7    face recognition     9.60     0.025     0.005
# 8              visual     9.50     0.324     0.216
# 9   occipito temporal     9.49     0.039     0.012
# 10           occipito     9.03     0.044     0.014
# 11            objects     8.57     0.099     0.048
# 12            viewing     8.52     0.074     0.032
# 13             facial     8.40     0.077     0.035
# 14        recognition     8.15     0.127     0.070
# ━━━ (42, 12, -18.5)  Frequency c3: Temporal pole (R)  [n=713 studies] ━━━
#                  term  z_score  p_active  p_global
# 0       temporal pole     8.25     0.045     0.012
# 1            amygdala     7.86     0.202     0.110
# 2              insula     7.76     0.241     0.140
# 3                pole     7.36     0.053     0.017
# 4            temporal     6.32     0.425     0.315
# 5    inferior frontal     5.23     0.198     0.132
# 6     fronto temporal     5.12     0.022     0.007
# 7   anterior temporal     4.99     0.035     0.013
# 8            anterior     4.95     0.356     0.274
# 9             neutral     4.93     0.109     0.064
# 10    amygdala insula     4.80     0.021     0.007
# 11           emotions     4.76     0.062     0.031
# 12          emotional     4.54     0.174     0.119
# 13             social     4.49     0.139     0.091
# 14   high functioning     4.41     0.017     0.005
# ━━━ (-24, -81, 34)  Frequency c4: Lateral occipital, superior (L)  [n=826 studies] ━━━
#                     term  z_score  p_active  p_global
# 0                 visual    10.24     0.363     0.216
# 1              occipital     9.36     0.201     0.102
# 2                sighted     8.63     0.027     0.005
# 3               parietal     7.19     0.401     0.288
# 4      superior parietal     6.71     0.091     0.043
# 5                spatial     6.19     0.163     0.099
# 6          intraparietal     5.84     0.090     0.047
# 7                 object     5.61     0.105     0.059
# 8     posterior parietal     5.57     0.068     0.033
# 9   intraparietal sulcus     5.55     0.077     0.040
# 10                   ips     5.43     0.038     0.015
# 11      representational     5.04     0.019     0.006
# 12              encoding     4.97     0.103     0.061
# 13     spatial attention     4.96     0.028     0.010
# 14      occipital cortex     4.87     0.050     0.024
# ━━━ (-3, 9, -1)  Frequency c5: Subcallosal cortex  [n=1359 studies] ━━━
#                   term  z_score  p_active  p_global
# 0             striatum    19.42     0.188     0.062
# 1               reward    19.13     0.191     0.064
# 2     ventral striatum    17.45     0.108     0.029
# 3             monetary    14.35     0.077     0.021
# 4            incentive    12.90     0.046     0.010
# 5         anticipation    11.85     0.067     0.021
# 6              nucleus    11.68     0.110     0.045
# 7             striatal    11.28     0.096     0.038
# 8            accumbens    11.13     0.049     0.014
# 9    nucleus accumbens    10.73     0.047     0.013
# 10             caudate    10.47     0.112     0.050
# 11     incentive delay    10.47     0.026     0.005
# 12             ventral    10.21     0.210     0.120
# 13             rewards     9.98     0.052     0.017
# 14  monetary incentive     9.64     0.025     0.006
# ━━━ (57, 18, 23.5)  Frequency c6: IFG pars opercularis (R)  [n=1209 studies] ━━━
#                    term  z_score  p_active  p_global
# 0      inferior frontal     7.57     0.205     0.132
# 1              inferior     7.07     0.321     0.235
# 2                   ifg     6.32     0.056     0.027
# 3             gyrus ifg     5.75     0.045     0.022
# 4               frontal     5.73     0.407     0.329
# 5                 tasks     5.45     0.212     0.155
# 6   prefrontal parietal     4.92     0.026     0.011
# 7           observation     4.72     0.045     0.024
# 8              involved     4.69     0.280     0.223
# 9         mirror neuron     4.60     0.018     0.007
# 10           prefrontal     4.55     0.366     0.306
# 11                 task     4.36     0.479     0.417
# 12        frontal gyrus     4.35     0.181     0.138
# 13              empathy     4.13     0.026     0.013
# 14             premotor     3.99     0.102     0.072
# ━━━ (0, -93, -8)  Frequency c7: Occipital pole  [n=504 studies] ━━━
#                 term  z_score  p_active  p_global
# 0             visual     6.70     0.339     0.216
# 1                 v1     6.64     0.032     0.007
# 2          occipital     6.24     0.187     0.102
# 3      visual cortex     5.87     0.081     0.034
# 4       early visual     5.17     0.032     0.009
# 5         correspond     5.04     0.024     0.006
# 6   occipital cortex     4.09     0.052     0.024
# 7      lingual gyrus     4.01     0.032     0.012
# 8            recruit     3.90     0.036     0.015
# 9            enables     3.86     0.020     0.006
# 10       effectively     3.83     0.022     0.007
# 11            vision     3.76     0.026     0.010
# 12           imagery     3.69     0.046     0.022
# 13          occipito     3.64     0.034     0.014
# 14           lingual     3.58     0.040     0.018

# %%
rsa_interaction_clusters = [
    ( 33, -84,   9.5, 'Interaction c1: Fusiform/lat. occipital (R)'),
    (-24, -48, -11.5, 'Interaction c2: Fusiform/lat. occipital (L)'),
    ( 45,   3,  34,   'Interaction c3: Precentral gyrus (R)'),
    (-39, -57,  13,   'Interaction c4: Angular gyrus (L)'),
]

rsa_interaction_results = decode_and_display(rsa_interaction_clusters)
# Out:
# ━━━ (33, -84, 9.5)  Interaction c1: Fusiform/lat. occipital (R)  [n=1032 studies] ━━━
#                   term  z_score  p_active  p_global
# 0            occipital    13.30     0.228     0.102
# 1               visual    12.60     0.378     0.216
# 2     occipital cortex     8.46     0.064     0.024
# 3     middle occipital     7.18     0.037     0.012
# 4   occipital temporal     7.12     0.023     0.006
# 5              objects     6.73     0.093     0.048
# 6     occipitotemporal     6.33     0.034     0.012
# 7      visual cortices     6.31     0.020     0.006
# 8                   v5     5.96     0.023     0.007
# 9              sighted     5.95     0.018     0.005
# 10          perceptual     5.85     0.104     0.060
# 11   lateral occipital     5.70     0.038     0.016
# 12        extrastriate     5.60     0.040     0.017
# 13                  mt     5.56     0.027     0.010
# 14            encoding     5.53     0.103     0.061
# ━━━ (-24, -48, -11.5)  Interaction c2: Fusiform/lat. occipital (L)  [n=973 studies] ━━━
#                       term  z_score  p_active  p_global
# 0          parahippocampal    13.64     0.129     0.042
# 1                 fusiform    11.26     0.158     0.068
# 2                   scenes    11.18     0.061     0.016
# 3                  objects     9.61     0.114     0.048
# 4                    scene     8.86     0.043     0.012
# 5   parahippocampal cortex     8.78     0.026     0.005
# 6               navigation     8.25     0.025     0.005
# 7              hippocampal     7.53     0.086     0.039
# 8    parahippocampal gyrus     7.49     0.059     0.023
# 9          medial temporal     7.16     0.072     0.032
# 10    anterior hippocampus     7.15     0.023     0.006
# 11                   place     7.09     0.039     0.013
# 12                  object     6.98     0.112     0.059
# 13          fusiform gyrus     6.76     0.083     0.040
# 14             hippocampus     6.17     0.125     0.074
# ━━━ (45, 3, 34)  Interaction c3: Precentral gyrus (R)  [n=1832 studies] ━━━
#                term  z_score  p_active  p_global
# 0          parietal     7.50     0.367     0.288
# 1              task     7.44     0.503     0.417
# 2             tasks     7.23     0.216     0.155
# 3   task difficulty     6.03     0.025     0.011
# 4           frontal     5.83     0.394     0.329
# 5          premotor     5.68     0.106     0.072
# 6      interference     5.45     0.042     0.023
# 7           working     5.43     0.112     0.078
# 8    working memory     5.37     0.109     0.076
# 9       frontal eye     5.30     0.025     0.012
# 10        attention     5.30     0.169     0.127
# 11       difficulty     5.30     0.049     0.029
# 12         stimulus     5.13     0.158     0.119
# 13       eye fields     5.03     0.018     0.008
# 14           visual     5.02     0.265     0.216
# ━━━ (-39, -57, 13)  Interaction c4: Angular gyrus (L)  [n=698 studies] ━━━
#                   term  z_score  p_active  p_global
# 0             temporal     8.73     0.468     0.315
# 1      middle temporal     6.83     0.107     0.051
# 2              lexical     6.54     0.060     0.023
# 3             gestures     6.35     0.024     0.006
# 4       temporal gyrus     5.85     0.139     0.079
# 5    superior temporal     5.32     0.159     0.099
# 6            posterior     5.29     0.307     0.223
# 7               motion     5.23     0.066     0.031
# 8             language     5.20     0.129     0.077
# 9           linguistic     5.09     0.050     0.022
# 10   temporal parietal     4.82     0.037     0.015
# 11  posterior superior     4.80     0.052     0.024
# 12              social     4.72     0.142     0.091
# 13     temporal sulcus     4.64     0.069     0.036
# 14                 tom     4.64     0.019     0.006

# %% [markdown]
# ### Findings
#
# 1. **Frequency c2 (R fusiform, 42,-54,-18.5) decodes as literally the fusiform
#    face area**: top terms `face` (z=23.1), `fusiform` (22.5), `faces` (20.3),
#    `fusiform face`, `ffa` — the FFA meta-analytic signature, not a generic
#    visual/object region. Worth noting given face is one of the four stimulus
#    categories in this task.
#
# 2. **Frequency c5 (Subcallosal cortex, -3,9,-1) decodes as classic reward/
#    valuation territory**: `striatum` (19.4), `reward` (19.1), `ventral
#    striatum` (17.5), `monetary`, `incentive`, `nucleus accumbens`,
#    `incentive delay` — this is meta-analytically a value/reward hub, even
#    though it only reached significance for the **frequency** term (not
#    value) in the searchlight. Candidate follow-up: check whether this
#    voxel's β(value) trends the same direction, given the ROI-level
#    vmPFC/value result nearby.
#
# 3. **Interaction c2 (L fusiform/parahippocampal, -24,-48,-11.5) leans
#    scene/place-selective, not purely face/object**: `parahippocampal`
#    (13.6), `fusiform` (11.3), `scenes`, `scene`, `place`,
#    `parahippocampal gyrus` — closer to the parahippocampal place area (PPA)
#    than FFA, unlike the frequency map's R-hemisphere fusiform peak (c2
#    above, which is FFA-like). The two large interaction clusters may not be
#    functionally homogeneous despite both landing in "fusiform" anatomically.
#
# 4. **Interaction c3/c4 (precentral, angular) are generic task/attention and
#    language/social-cognition hubs respectively** — `task`, `working memory`,
#    `attention`, `premotor` for c3; `temporal`, `language`, `linguistic`,
#    `tom` (theory of mind) for c4. Neither has a term profile as specific or
#    interpretable as the two fusiform clusters; likely secondary to the main
#    effect rather than a distinct finding.
#
# 5. **Frequency c3 (Temporal pole) and c6 (IFG) decode consistently with
#    their anatomical labels** — c3: `temporal pole`, `amygdala`, `insula`
#    (semantic/emotional integration territory); c6: `inferior frontal`,
#    `ifg`, `mirror neuron`, `premotor` (classic IFG/action-observation
#    profile). No surprises, included for completeness.
