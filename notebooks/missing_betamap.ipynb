# %%
import sys
import os
import numpy as np
import pickle
import time
import json
import pandas as pd

sys.path.append('/home/ubuntu/repos/learning-habits-analysis')
from utils.data import load_participant_list

from concurrent.futures import ProcessPoolExecutor, as_completed

# %%
# Define directories and parameters
base_dir = '/home/ubuntu/data/learning-habits'
bids_dir = "/home/ubuntu/data/learning-habits/bids_dataset/derivatives/fmriprep-24.0.1"
derivatives_dir = os.path.join(os.path.dirname(bids_dir), 'nilearn')

# %%
# Load model parameters from the previously saved JSON file
params_path = os.path.join(derivatives_dir, 'ck_modulation_20250127','sub-01','run-test', 'sub-01_run-test_params.json')  # Adjust date if needed
with open(params_path, 'r') as f:
    model_params = json.load(f)

# Define the parametric modulator column
parametric_modulator_column = 'first_stim_value_ck'

# %%
sub_ids = load_participant_list(base_dir)

# %%
for sub_id in sub_ids:
    print(f"Processing Subject {sub_id}...")
    model_dir = os.path.join(derivatives_dir, f"{model_params['model_name']}_20250126", f"sub-{sub_id}")
    assert os.path.exists(model_dir)
    run='learning1'
    run_path = os.path.join(model_dir, f"run-{run}")
    assert os.path.exists(run_path)
    # Load the saved model
    model_filename = os.path.join(run_path, f'sub-sub-{sub_id}_run-{run}_model.pkl')
    assert os.path.exists(model_filename)
    with open(model_filename, 'rb') as f:
        model = pickle.load(f)
    # Load the design matrix to extract columns
    design_matrix_path = os.path.join(run_path, f'sub-{sub_id}_run-{run}_design_matrix.csv')

    design_matrix = pd.read_csv(design_matrix_path)
    # Compute and save beta map for the parametric modulator
    idx = design_matrix.columns.get_loc(parametric_modulator_column)
    beta_map = model.compute_contrast(np.eye(len(design_matrix.columns))[idx], output_type='effect_size')
    beta_path = os.path.join(run_path, f'beta_{parametric_modulator_column}.nii.gz')
    beta_map.to_filename(beta_path)
    print(f"Saved: {beta_path}")
# Out:
# Processing Subject 01...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-01/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 02...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-02/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 03...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-03/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 04...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-04/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 05...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-05/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 06...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-06/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 07...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-07/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 08...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-08/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 09...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-09/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 10...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-10/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 12...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-12/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 13...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-13/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 14...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-14/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 15...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-15/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 16...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-16/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 18...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-18/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 19...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-19/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 20...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-20/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 21...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-21/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 22...
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7fbd8d051c60>>
# Traceback (most recent call last):
#   File "/home/ubuntu/miniforge3/envs/neuroim/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 770, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-22/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 23...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-23/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 24...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-24/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 26...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-26/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 27...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-27/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 28...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-28/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 29...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-29/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 30...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-30/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 33...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-33/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 34...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-34/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 35...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-35/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 36...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-36/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 37...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-37/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 38...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-38/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 40...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-40/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 41...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-41/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 43...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-43/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 45...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-45/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 47...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-47/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 48...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-48/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 49...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-49/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 50...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-50/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 51...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-51/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 52...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-52/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 53...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-53/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 54...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-54/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 55...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-55/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 56...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-56/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 57...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-57/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 58...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-58/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 59...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-59/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 60...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-60/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 61...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-61/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 62...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-62/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 63...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-63/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 64...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-64/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 65...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-65/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 67...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-67/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 69...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-69/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 70...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-70/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 71...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-71/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 72...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-72/run-learning1/beta_first_stim_value_rl.nii.gz
# Processing Subject 73...
# Saved: /home/ubuntu/data/learning-habits/bids_dataset/derivatives/nilearn/rl_modulation_20250126/sub-73/run-learning1/beta_first_stim_value_rl.nii.gz
