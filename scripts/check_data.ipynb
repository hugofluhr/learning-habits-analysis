# %%
import pandas as pd
import datetime

# %%
base_data_dir = '/Users/hugofluhr/phd_local/data/LearningHabits'
participants_info_path = '/Users/hugofluhr/phd_local/data/LearningHabits/Participant_Documentation.xlsx'

# %%
subj_info = pd.read_excel(participants_info_path)

# %%
# Get the current date
current_date = datetime.date.today().strftime("%Y-%m-%d")
# Filter the dataframe to select rows where "Date MRI" is in the past
acquired = subj_info[subj_info["Date MRI"] < current_date]
# Display the selected rows
acquired
# Out:
#         ID Initials   Date MRI  Time MRI email online email reminder  \
# 0   D06D5S      ADN 2024-04-23  08:00:00   2024-04-19     2024-04-22
# 1   d11e9v      AEH 2024-04-23  09:45:00   2024-04-19     2024-04-22
# 2   c12n0m       LN 2024-04-25  08:00:00   2024-04-19     2024-04-22
# 3   j01e2z       XE 2024-04-25  09:45:00   2024-04-19     2024-04-22
# 4   b12z2f       BZ 2024-04-25  15:00:00   2024-04-19     2024-04-22
# 5   h04b9k       SB 2024-04-26  08:00:00   2024-04-19     2024-04-24
# 6   c05s4p      IMS 2024-04-26  09:45:00   2024-04-19     2024-04-24
# 7   k09y9h      KLY 2024-04-29  08:00:00   2024-04-25     2024-04-28
# 8   y01h8s       LH 2024-04-29  09:45:00   2024-04-24     2024-04-28
# 9   b06g3a       GG 2024-04-30  08:00:00   2024-04-24     2024-04-28
# 10  c07g3u       LG 2024-04-30  09:45:00   2024-04-24     2024-04-28
# 11  e05p0m       EP 2024-05-02  08:00:00   2024-04-30            NaT
# 12  h06w8d       KW 2024-05-02  09:45:00   2024-04-25     2024-04-30
# ...

# %%
acquired_subj = acquired['ID'].str.lower().values

# %%
for sub in acquired_subj:
    # MRI data

    # RP data

    # Eye tracking data

    # GoNoGo data
